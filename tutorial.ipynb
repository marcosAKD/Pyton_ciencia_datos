# %% [markdown]
# <a href="https://colab.research.google.com/github/marcosAKD/Pyton_ciencia_datos/blob/main/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Escudo_de_Racing_Club_(2014).svg.png](data:image/png;base64,...)

# %%
# ESTE ES UN COMENTARIO EN PYTON
print("hola mundo")
# Out:
# hola mundo
